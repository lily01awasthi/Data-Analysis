# %% [markdown]
# <a href="https://www.kaggle.com/code/lalitaawasthi/5-day-data-challenge?scriptVersionId=127575180" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind
import seaborn as sns
from scipy import stats 

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# read dataset into a dataframe
df = pd.read_csv('/kaggle/input/80-cereals/cereal.csv')
# print(df)

#Histogram of three different cereals and their calories
name = df['name']
calories = df['calories']
plt.bar(name[0:3],calories[0:3])
plt.title("Histogram of 3 different cereals with respect to thier caliries ")

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/80-cereals/cereal.csv
# Text(0.5, 1.0, 'Histogram of 3 different cereals with respect to thier caliries ')

# %%
# performing T-test for compairing between two different type of cereals
cereal_1 = df['sugars'][df["mfr"] == "K"]
cereal_2 = df['sugars'][df["mfr"] == "Q"]
ttest_ind(cereal_1,cereal_2,equal_var=False)
print("Since the  pvalue=0.27> 0.01. This is evident that it is unlikely that the both data are from same distribution.")

# Histogram for two different groups of manufacturers with respect to their sugar content in cereals
plt.hist(cereal_1,label="manufactirer_K")
plt.hist(cereal_2, label="manufactirer_Q")
plt.legend(loc="upper right")
print("From the histogram we can see that the manufacturer Q has cereals with less sugar content than K")
# Out:
# Since the  pvalue=0.27> 0.01. This is evident that it is unlikely that the both data are from same distribution.
# From the histogram we can see that the manufacturer Q has cereals with less sugar content than K

# %%
# Visualizing categorical data with bar chart
manufacturers = df["mfr"]
protein = df["protein"]
sns.barplot(data=df, x=manufacturers, y=protein)
plt.title("Manufacturer and the amount of protein in their Cereals")
print("Hence, from the barplot we can see the protein content in the cereals and their manufacturers. Manufacturer 'A' seem to have the maximum protein content in their cereals which in 4.0")
# Out:
# Hence, from the barplot we can see the protein content in the cereals and their manufacturers. Manufacturer 'A' seem to have the maximum protein content in their cereals which in 4.0

# %%
manufacturers = df["mfr"].value_counts()
Type = df["type"].value_counts()
crosstab=pd.crosstab(df['mfr'],df['type'])
stats.chi2_contingency(crosstab)
print("Here, we have, chi_square_value=31.37, p_value=2.149>0.05: which means it is unlikely that there is a connection between manufacturer and the type of cereal. degree of freedom =6")
print("Final array is the expected frequencies based on the marginal sums of the table.")
# Out:
# Here, we have, chi_square_value=31.37, p_value=2.149>0.05: which means it is unlikely that there is a connection between manufacturer and the type of cereal. degree of freedom =6
# Final array is the expected frequencies based on the marginal sums of the table.
